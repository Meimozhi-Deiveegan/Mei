# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("covid_19_clean_complete _1_.csv")

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
df.tail()
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa

# %%
df.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
df.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# show number of confirmed,recover and death cases

# %%
df.groupby("Country/Region").sum()
# Out:
#                             Lat          Long  Confirmed  Deaths  Recovered  \
# Country/Region
# Afghanistan         6380.552680  12729.471164    1936390   49098     798240
# Albania             7736.820400   3791.640400     196702    5708     118877
# Algeria             5270.373200    312.004800    1179755   77972     755897
# Andorra             7991.184400    286.098400      94404    5423      69074
# Angola             -2106.107600   3360.293200      22662    1078       6573
# ...                         ...           ...        ...     ...        ...
# West Bank and Gaza  6007.013600   6623.841600     233461    1370      61124
# Western Sahara      4552.514000  -2422.530400        901      63        648
# Yemen               2923.912676   9121.080944      67180   17707      23779
# Zambia             -2469.172636   5235.674416     129421    2643      83611
# Zimbabwe           -3574.902344   5481.113116      50794     881      12207
#
#                      Active
# ...

# %%
df.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Country/Region
# US                       224345948
# Brazil                    89524967
# Russia                    45408411
# India                     40883464
# Spain                     27404045
#                            ...
# Saint Kitts and Nevis         1772
# Greenland                     1507
# Holy See                      1356
# Papua New Guinea              1185
# Western Sahara                 901
# Name: Confirmed, Length: 187, dtype: int64

# %%
df.groupby('Country/Region')['Confirmed','Recovered','Deaths'].sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13392\1268884781.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Country/Region')['Confirmed','Recovered','Deaths'].sum()
#                     Confirmed  Recovered  Deaths
# Country/Region
# Afghanistan           1936390     798240   49098
# Albania                196702     118877    5708
# Algeria               1179755     755897   77972
# Andorra                 94404      69074    5423
# Angola                  22662       6573    1078
# ...                       ...        ...     ...
# West Bank and Gaza     233461      61124    1370
# Western Sahara            901        648      63
# Yemen                   67180      23779   17707
# Zambia                 129421      83611    2643
# Zimbabwe                50794      12207     881
#
# [187 rows x 3 columns]

# %% [markdown]
# Remove all the records where confirmed cases is less than 10

# %%
df[df.Confirmed<10]
# Out:
#                   Province/State  Country/Region       Lat        Long  \
# 0                            NaN     Afghanistan  33.93911   67.709953
# 1                            NaN         Albania  41.15330   20.168300
# 2                            NaN         Algeria  28.03390    1.659600
# 3                            NaN         Andorra  42.50630    1.521800
# 4                            NaN          Angola -11.20270   17.873900
# ...                          ...             ...       ...         ...
# 48918           Saint Barthelemy          France  17.90000  -62.833300
# 49048      Northwest Territories          Canada  64.82550 -124.845700
# 49052                   Anguilla  United Kingdom  18.22060  -63.068600
# 49053     British Virgin Islands  United Kingdom  18.42070  -64.640000
# 49060  Saint Pierre and Miquelon          France  46.88520  -56.315900
#
#              Date  Confirmed  Deaths  Recovered  Active             WHO Region
# ...

# %%
df=df[~df.Confirmed<10]

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %% [markdown]
# which region maximum number of confirmed cases were recorded

# %%
df.groupby('Country/Region').Confirmed.sum().sort_values(ascending=False)
# Out:
# Country/Region
# US                       224345948
# Brazil                    89524967
# Russia                    45408411
# India                     40883464
# Spain                     27404045
#                            ...
# Saint Kitts and Nevis         1772
# Greenland                     1507
# Holy See                      1356
# Papua New Guinea              1185
# Western Sahara                 901
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# In which region minimum no.of death cases were recorded

# %%
df.groupby("Country/Region").Deaths.sum().sort_values(ascending=True).head(20)
# Out:
# Country/Region
# Fiji                                 0
# Cambodia                             0
# Dominica                             0
# Eritrea                              0
# Seychelles                           0
# Greenland                            0
# Grenada                              0
# Timor-Leste                          0
# Holy See                             0
# Vietnam                              0
# Saint Lucia                          0
# Saint Kitts and Nevis                0
# Laos                                 0
# Mongolia                             0
# Saint Vincent and the Grenadines     0
# Bhutan                               0
# Papua New Guinea                     2
# Uganda                               6
# Western Sahara                      63
# Namibia                             72
# Name: Deaths, dtype: int64

# %%
df.sort_values(by=['Recovered'],ascending=False)
# Out:
#       Province/State Country/Region        Lat       Long        Date  \
# 48835            NaN         Brazil -14.235000 -51.925300  2020-07-27
# 48574            NaN         Brazil -14.235000 -51.925300  2020-07-26
# 48313            NaN         Brazil -14.235000 -51.925300  2020-07-25
# 48052            NaN         Brazil -14.235000 -51.925300  2020-07-24
# 47791            NaN         Brazil -14.235000 -51.925300  2020-07-23
# ...              ...            ...        ...        ...         ...
# 10785            NaN     Costa Rica   9.748900 -83.753400  2020-03-03
# 10786            NaN  Cote d'Ivoire   7.540000  -5.547100  2020-03-03
# 10787            NaN        Croatia  45.100000  15.200000  2020-03-03
# 10788            NaN           Cuba  21.521757 -77.781167  2020-03-03
# 0                NaN    Afghanistan  33.939110  67.709953  2020-01-22
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# ...

# %%
agg=df.groupby("Country/Region").sum()

# %%
agg
# Out:
#                             Lat          Long  Confirmed  Deaths  Recovered  \
# Country/Region
# Afghanistan         6380.552680  12729.471164    1936390   49098     798240
# Albania             7736.820400   3791.640400     196702    5708     118877
# Algeria             5270.373200    312.004800    1179755   77972     755897
# Andorra             7991.184400    286.098400      94404    5423      69074
# Angola             -2106.107600   3360.293200      22662    1078       6573
# ...                         ...           ...        ...     ...        ...
# West Bank and Gaza  6007.013600   6623.841600     233461    1370      61124
# Western Sahara      4552.514000  -2422.530400        901      63        648
# Yemen               2923.912676   9121.080944      67180   17707      23779
# Zambia             -2469.172636   5235.674416     129421    2643      83611
# Zimbabwe           -3574.902344   5481.113116      50794     881      12207
#
#                      Active
# ...

# %%
agg.loc['India'].plot()
agg.loc['Spain'].plot()
agg.loc['Italy'].plot()
plt.legend()

# %%
agg.loc['India'].plot()
# Out:
# <AxesSubplot:>

# %%
agg.loc['India'][:3].plot()
# Out:
# <AxesSubplot:>

# %%
agg.loc['India'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
agg.loc['India'].diff().max()
# Out:
# 40868618.97856

# %%
agg.loc['Italy'].diff().max()
# Out:
# 26742782.33256

# %%
agg.loc['China'].diff().max()
# Out:
# 13438481.7124

# %% [markdown]
# Find maximum infection rate for all countries

# %%
countries=list(agg.index)
max_infection_rates=[]
for c in countries:
    max_infection_rates.append(agg.loc[c].diff().max())
agg["max_infection_rates"]=max_infection_rates

# %%
agg.head()
# Out:
#                        Lat          Long  Confirmed  Deaths  Recovered  \
# Country/Region
# Afghanistan     6380.55268  12729.471164    1936390   49098     798240
# Albania         7736.82040   3791.640400     196702    5708     118877
# Algeria         5270.37320    312.004800    1179755   77972     755897
# Andorra         7991.18440    286.098400      94404    5423      69074
# Angola         -2106.10760   3360.293200      22662    1078       6573
#
#                  Active  max_infection_rates
# Country/Region
# Afghanistan     1089052         1.923661e+06
# Albania           72117         1.929104e+05
# Algeria          345886         1.179443e+06
# Andorra           19907         9.411790e+04
# Angola            15011         1.930171e+04
